# %% [markdown]
# ## Search Tool

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke("Who is monkey D. luffy")

results
# Out:
# 'Monkey D. Luffy (モンキー・D・ルフィ, Monkī Dī Rufi) is the captain of the Straw Hat Pirates and the main protagonist of the One Piece franchise. At age seven, he admires and tries to join the pirates of the "Red-Haired" Shanks. Monkey D. Luffy is the series\' main protagonist, a young pirate who wishes to succeed Gold Roger, the deceased King of the Pirates, by finding his treasure, the "One Piece". Get to know Monkey D. Luffy, the leader of the Straw Hat Pirates. Learn about his key relationships, special abilities, backstory, and motivation, as well as everything that happened to Luffy in ONE PIECE Seasons 1 and 2. Monkey D. Luffy, also known as "Straw Hat Luffy," is the main protagonist of the manga and anime series One Piece. As captain of the increasingly infamous and powerful Straw Hat Pirates, his dream is to find the legendary treasure, the One Piece, and become the King of the Pirates. Despite not focusing on the background of Monkey D. Luffy, it seems that Oda has revealed a prime candidate for Luffy\'s mother, and this person is currently playing a big role in the plot of the ...'

# %% [markdown]
# ## Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

shell_tool.invoke("whoami")
# Out:
# Executing command:
#  whoami
# /home/xyren/coding/learning/ai-engineering/.venv/lib/python3.14/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
# 'xyren\n'
